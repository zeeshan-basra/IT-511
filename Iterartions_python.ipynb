# %%
for i in range(0,10):
    for j in range(0,i):
        print('*',end = ' ')
    print('')
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *

# %%
for i in range(10):
    for k in range(i,10):
            print(' ',end = ' ')
    for j in range(i*2):
        print('*',end = ' ')
    print('')
# Out:
#
#                   * *
#                 * * * *
#               * * * * * *
#             * * * * * * * *
#           * * * * * * * * * *
#         * * * * * * * * * * * *
#       * * * * * * * * * * * * * *
#     * * * * * * * * * * * * * * * *
#   * * * * * * * * * * * * * * * * * *
